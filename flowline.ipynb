# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('aslak')
import pandas as pd
import density_core
from settings import *
from grinsted_firn_model import *

# %%
#exx(t),exy(t),eyy(t)
#T(t)
#bdot(t)
#rho_s

#updated:
#rho(age)
#uxx,uxy,uyy,uzz accumulated strain as a function of age 
dt = 10 #year

ezz = -0.05
H = 1
uxx,uxy,uyy,uzz = 0,0,0,0
for i in range(10):
    duzz = np.exp(dt*ezz)-1
    
    uzz = (uzz+1)*(1+duzz)-1
    H = H*(1 + duzz)
    print(i,duzz,uzz,H)
# Out:
# 0 -0.3934693402873666 -0.3934693402873666 0.6065306597126334
# 1 -0.3934693402873666 -0.6321205588285577 0.36787944117144233
# 2 -0.3934693402873666 -0.7768698398515701 0.22313016014842985
# 3 -0.3934693402873666 -0.8646647167633873 0.1353352832366127
# 4 -0.3934693402873666 -0.9179150013761012 0.0820849986238988
# 5 -0.3934693402873666 -0.950212931632136 0.049787068367863944
# 6 -0.3934693402873666 -0.9698026165776815 0.0301973834223185
# 7 -0.3934693402873666 -0.9816843611112658 0.01831563888873418
# 8 -0.3934693402873666 -0.9888910034617576 0.011108996538242306
# 9 -0.3934693402873666 -0.9932620530009145 0.006737946999085467

# %%
np.exp(-3.934693402873666)
# Out:
# 0.019551692901480067
